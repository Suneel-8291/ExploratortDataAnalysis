# %%
import pandas as pd
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data.csv",encoding = 'ISO-8859-1')

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
d = {
    'InvoiceNo' : 'invoice_num',
    'StockCode' : 'stock_code',
    'Description' : 'description',
    'Quantity' : 'quantity',
    'InvoiceDate' : 'invoice_date',
    'UnitPrice' : 'unit_price',
    'CustomerID' : 'customer_id',
    'Country' : 'country'
}

# %%
df.rename(columns = d,inplace = True)

# %%
df.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'country'],
#       dtype='object')

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.dtypes
# Out:
# invoice_num      object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   541909 non-null  object
#  1   stock_code    541909 non-null  object
#  2   description   540455 non-null  object
#  3   quantity      541909 non-null  int64
#  4   invoice_date  541909 non-null  object
#  5   unit_price    541909 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
df.isnull().sum()
# Out:
# invoice_num          0
# stock_code           0
# description       1454
# quantity             0
# invoice_date         0
# unit_price           0
# customer_id     135080
# country              0
# dtype: int64

# %%
df.isnull().sum().sort_values()
# Out:
# invoice_num          0
# stock_code           0
# quantity             0
# invoice_date         0
# country              0
# unit_price           0
# description       1454
# customer_id     135080
# dtype: int64

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# customer_id     135080
# description       1454
# stock_code           0
# invoice_num          0
# quantity             0
# invoice_date         0
# unit_price           0
# country              0
# dtype: int64

# %%
new_df = df.dropna()

# %%
new_df.isna().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %%
new_df.dtypes
# Out:
# invoice_num      object
# stock_code       object
# description      object
# quantity          int64
# invoice_date     object
# unit_price      float64
# customer_id     float64
# country          object
# dtype: object

# %%
new_df['invoice_date'] = pd.to_datetime(new_df.invoice_date)

# %%
new_df.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id            float64
# country                 object
# dtype: object

# %%
new_df.head(2)
# Out:
#   invoice_num stock_code                         description  quantity  \
# 0      536365     85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                 WHITE METAL LANTERN         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
new_df.description.str.lower()
# Out:
# 0          white hanging heart t-light holder
# 1                         white metal lantern
# 2              cream cupid hearts coat hanger
# 3         knitted union flag hot water bottle
# 4              red woolly hottie white heart.
#                          ...
# 541904            pack of 20 spaceboy napkins
# 541905           children's apron dolly girl
# 541906          childrens cutlery dolly girl
# 541907        childrens cutlery circus parade
# 541908          baking set 9 piece retrospot
# Name: description, Length: 406829, dtype: object

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1      536365      71053                  WHITE METAL LANTERN         6
# 2      536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3      536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4      536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
new_df['description'] = new_df.description.str.lower()

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55      17850.0  United Kingdom
# 1 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 2 2010-12-01 08:26:00        2.75      17850.0  United Kingdom
# 3 2010-12-01 08:26:00        3.39      17850.0  United Kingdom
# 4 2010-12-01 08:26:00        3.39      17850.0  United Kingdom

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  float64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 27.9+ MB

# %%
new_df.customer_id
# Out:
# 0         17850.0
# 1         17850.0
# 2         17850.0
# 3         17850.0
# 4         17850.0
#            ...
# 541904    12680.0
# 541905    12680.0
# 541906    12680.0
# 541907    12680.0
# 541908    12680.0
# Name: customer_id, Length: 406829, dtype: float64

# %%
new_df['customer_id'] = new_df['customer_id'].astype(int)

# %%
new_df.dtypes
# Out:
# invoice_num             object
# stock_code              object
# description             object
# quantity                 int64
# invoice_date    datetime64[ns]
# unit_price             float64
# customer_id              int64
# country                 object
# dtype: object

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 406829 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   invoice_num   406829 non-null  object
#  1   stock_code    406829 non-null  object
#  2   description   406829 non-null  object
#  3   quantity      406829 non-null  int64
#  4   invoice_date  406829 non-null  datetime64[ns]
#  5   unit_price    406829 non-null  float64
#  6   customer_id   406829 non-null  int64
#  7   country       406829 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(2), object(4)
# memory usage: 27.9+ MB

# %%
new_df.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  406829.000000                         406829  406829.000000
# mean       12.061303  2011-07-10 16:30:57.879207424       3.460471
# min    -80995.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-06 15:02:00       1.250000
# 50%         5.000000            2011-07-31 11:48:00       1.950000
# 75%        12.000000            2011-10-20 13:06:00       3.750000
# max     80995.000000            2011-12-09 12:50:00   38970.000000
# std       248.693370                            NaN      69.315162
#
#          customer_id
# count  406829.000000
# mean    15287.690570
# min     12346.000000
# 25%     13953.000000
# 50%     15152.000000
# 75%     16791.000000
# max     18287.000000
# std      1713.600303

# %%
a = new_df.quantity > 0

# %%
new_df = new_df[a]

# %%
new_df.describe()
# Out:
#             quantity                   invoice_date     unit_price  \
# count  397924.000000                         397924  397924.000000
# mean       13.021823  2011-07-10 23:43:36.912475648       3.116174
# min         1.000000            2010-12-01 08:26:00       0.000000
# 25%         2.000000            2011-04-07 11:12:00       1.250000
# 50%         6.000000            2011-07-31 14:39:00       1.950000
# 75%        12.000000            2011-10-20 14:33:00       3.750000
# max     80995.000000            2011-12-09 12:50:00    8142.750000
# std       180.420210                            NaN      22.096788
#
#          customer_id
# count  397924.000000
# mean    15294.315171
# min     12346.000000
# 25%     13969.000000
# 50%     15159.000000
# 75%     16795.000000
# max     18287.000000
# std      1713.169877

# %%
new_df.isna().sum()
# Out:
# invoice_num     0
# stock_code      0
# description     0
# quantity        0
# invoice_date    0
# unit_price      0
# customer_id     0
# country         0
# dtype: int64

# %%
new_df.shape
# Out:
# (397924, 8)

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom

# %%
new_df['amount_spent'] = new_df.quantity * new_df.unit_price

# %%
new_df.head()
# Out:
#   invoice_num stock_code                          description  quantity  \
# 0      536365     85123A   white hanging heart t-light holder         6
# 1      536365      71053                  white metal lantern         6
# 2      536365     84406B       cream cupid hearts coat hanger         8
# 3      536365     84029G  knitted union flag hot water bottle         6
# 4      536365     84029E       red woolly hottie white heart.         6
#
#          invoice_date  unit_price  customer_id         country  amount_spent
# 0 2010-12-01 08:26:00        2.55        17850  United Kingdom         15.30
# 1 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 2 2010-12-01 08:26:00        2.75        17850  United Kingdom         22.00
# 3 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34
# 4 2010-12-01 08:26:00        3.39        17850  United Kingdom         20.34

# %%
for i in new_df.columns:
    print(i)
# Out:
# invoice_num
# stock_code
# description
# quantity
# invoice_date
# unit_price
# customer_id
# country
# amount_spent

# %%
new_df.shape
# Out:
# (397924, 9)

# %%
new_df.columns
# Out:
# Index(['invoice_num', 'stock_code', 'description', 'quantity', 'invoice_date',
#        'unit_price', 'customer_id', 'country', 'amount_spent'],
#       dtype='object')

# %%
col_order = ['invoice_num', 'invoice_date','stock_code', 'description', 'quantity', 
       'unit_price', 'amount_spent', 'customer_id', 'country']

# %%
new_df = new_df[col_order]

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date stock_code  \
# 0      536365 2010-12-01 08:26:00     85123A
# 1      536365 2010-12-01 08:26:00      71053
# 2      536365 2010-12-01 08:26:00     84406B
# 3      536365 2010-12-01 08:26:00     84029G
# 4      536365 2010-12-01 08:26:00     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# 2        17850  United Kingdom
# 3        17850  United Kingdom
# 4        17850  United Kingdom

# %%
new_df.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %%
new_df.invoice_date.dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 541904    2011
# 541905    2011
# 541906    2011
# 541907    2011
# 541908    2011
# Name: invoice_date, Length: 397924, dtype: int32

# %%
c1 = 'year_month'

# %%
v1 = new_df['invoice_date'].map(lambda a : str(a.year) + str(a.month))

# %%
new_df.insert(loc = 2,column = c1,value = v1)

# %%
new_df.dtypes
# Out:
# invoice_num             object
# invoice_date    datetime64[ns]
# year_month              object
# stock_code              object
# description             object
# quantity                 int64
# unit_price             float64
# amount_spent           float64
# customer_id              int64
# country                 object
# dtype: object

# %%
new_df['year_month'] =  new_df.year_month.astype(int)

# %%
new_df.dtypes
# Out:
# invoice_num             object
# invoice_date    datetime64[ns]
# year_month               int64
# stock_code              object
# description             object
# quantity                 int64
# unit_price             float64
# amount_spent           float64
# customer_id              int64
# country                 object
# dtype: object

# %%
c2 = 'month'

# %%
v2 = new_df['invoice_date'].dt.month

# %%
new_df.insert(loc = 3,column = c2,value = v2)

# %%
new_df.dtypes
# Out:
# invoice_num             object
# invoice_date    datetime64[ns]
# year_month               int64
# month                    int32
# stock_code              object
# description             object
# quantity                 int64
# unit_price             float64
# amount_spent           float64
# customer_id              int64
# country                 object
# dtype: object

# %%
new_df.invoice_date
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: invoice_date, Length: 397924, dtype: datetime64[ns]

# %%
new_df.invoice_date.dt.dayofweek
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
#          ..
# 541904    4
# 541905    4
# 541906    4
# 541907    4
# 541908    4
# Name: invoice_date, Length: 397924, dtype: int32

# %%
c3 = 'day'

# %%
v3 = (new_df.invoice_date.dt.dayofweek) + 1

# %%
new_df.insert(loc = 4,column = c3,value = v3)

# %%
new_df
# Out:
#        invoice_num        invoice_date  year_month  month  day stock_code  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1           536365 2010-12-01 08:26:00      201012     12    3      71053
# 2           536365 2010-12-01 08:26:00      201012     12    3     84406B
# 3           536365 2010-12-01 08:26:00      201012     12    3     84029G
# 4           536365 2010-12-01 08:26:00      201012     12    3     84029E
# ...            ...                 ...         ...    ...  ...        ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5      22613
# 541905      581587 2011-12-09 12:50:00      201112     12    5      22899
# 541906      581587 2011-12-09 12:50:00      201112     12    5      23254
# 541907      581587 2011-12-09 12:50:00      201112     12    5      23255
# 541908      581587 2011-12-09 12:50:00      201112     12    5      22138
#
#                                 description  quantity  unit_price  \
# ...

# %%
new_df.dtypes
# Out:
# invoice_num             object
# invoice_date    datetime64[ns]
# year_month               int64
# month                    int32
# day                      int32
# stock_code              object
# description             object
# quantity                 int64
# unit_price             float64
# amount_spent           float64
# customer_id              int64
# country                 object
# dtype: object

# %%
new_df.day
# Out:
# 0         3
# 1         3
# 2         3
# 3         3
# 4         3
#          ..
# 541904    5
# 541905    5
# 541906    5
# 541907    5
# 541908    5
# Name: day, Length: 397924, dtype: int32

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom
# ...

# %%
a = new_df.invoice_date.dt.hour

# %%
new_df.insert(loc=5,column = 'hour',value = a)

# %%
new_df
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 0           536365 2010-12-01 08:26:00      201012     12    3     8
# 1           536365 2010-12-01 08:26:00      201012     12    3     8
# 2           536365 2010-12-01 08:26:00      201012     12    3     8
# 3           536365 2010-12-01 08:26:00      201012     12    3     8
# 4           536365 2010-12-01 08:26:00      201012     12    3     8
# ...            ...                 ...         ...    ...  ...   ...
# 541904      581587 2011-12-09 12:50:00      201112     12    5    12
# 541905      581587 2011-12-09 12:50:00      201112     12    5    12
# 541906      581587 2011-12-09 12:50:00      201112     12    5    12
# 541907      581587 2011-12-09 12:50:00      201112     12    5    12
# 541908      581587 2011-12-09 12:50:00      201112     12    5    12
#
#        stock_code                          description  quantity  unit_price  \
# ...

# %%
new_df.dtypes
# Out:
# invoice_num             object
# invoice_date    datetime64[ns]
# year_month               int64
# month                    int32
# day                      int32
# hour                     int32
# stock_code              object
# description             object
# quantity                 int64
# unit_price             float64
# amount_spent           float64
# customer_id              int64
# country                 object
# dtype: object

# %%
for i in new_df.columns:
    print(i)
# Out:
# invoice_num
# invoice_date
# year_month
# month
# day
# hour
# stock_code
# description
# quantity
# unit_price
# amount_spent
# customer_id
# country

# %%
new_df.groupby('customer_id').count()
# Out:
#              invoice_num  invoice_date  year_month  month  day  hour  \
# customer_id
# 12346                  1             1           1      1    1     1
# 12347                182           182         182    182  182   182
# 12348                 31            31          31     31   31    31
# 12349                 73            73          73     73   73    73
# 12350                 17            17          17     17   17    17
# ...                  ...           ...         ...    ...  ...   ...
# 18280                 10            10          10     10   10    10
# 18281                  7             7           7      7    7     7
# 18282                 12            12          12     12   12    12
# 18283                756           756         756    756  756   756
# 18287                 70            70          70     70   70    70
#
#              stock_code  description  quantity  unit_price  amount_spent  \
# customer_id
# ...

# %%
new_df.groupby(['customer_id','country']).count()
# Out:
#                             invoice_num  invoice_date  year_month  month  day  \
# customer_id country
# 12346       United Kingdom            1             1           1      1    1
# 12347       Iceland                 182           182         182    182  182
# 12348       Finland                  31            31          31     31   31
# 12349       Italy                    73            73          73     73   73
# 12350       Norway                   17            17          17     17   17
# ...                                 ...           ...         ...    ...  ...
# 18280       United Kingdom           10            10          10     10   10
# 18281       United Kingdom            7             7           7      7    7
# 18282       United Kingdom           12            12          12     12   12
# 18283       United Kingdom          756           756         756    756  756
# 18287       United Kingdom           70            70          70     70   70
#
# ...

# %%
new_df.groupby(['customer_id','country'])['invoice_num'].count()
# Out:
# customer_id  country
# 12346        United Kingdom      1
# 12347        Iceland           182
# 12348        Finland            31
# 12349        Italy              73
# 12350        Norway             17
#                               ...
# 18280        United Kingdom     10
# 18281        United Kingdom      7
# 18282        United Kingdom     12
# 18283        United Kingdom    756
# 18287        United Kingdom     70
# Name: invoice_num, Length: 4347, dtype: int64

# %%
# method 1
new_df.groupby(['customer_id','country'],as_index = False)['invoice_num'].count()
# Out:
#       customer_id         country  invoice_num
# 0           12346  United Kingdom            1
# 1           12347         Iceland          182
# 2           12348         Finland           31
# 3           12349           Italy           73
# 4           12350          Norway           17
# ...           ...             ...          ...
# 4342        18280  United Kingdom           10
# 4343        18281  United Kingdom            7
# 4344        18282  United Kingdom           12
# 4345        18283  United Kingdom          756
# 4346        18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
# method 2
new_df.groupby(['customer_id','country'])['invoice_num'].count().reset_index()
# Out:
#       customer_id         country  invoice_num
# 0           12346  United Kingdom            1
# 1           12347         Iceland          182
# 2           12348         Finland           31
# 3           12349           Italy           73
# 4           12350          Norway           17
# ...           ...             ...          ...
# 4342        18280  United Kingdom           10
# 4343        18281  United Kingdom            7
# 4344        18282  United Kingdom           12
# 4345        18283  United Kingdom          756
# 4346        18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
new_df.groupby(['customer_id','country'],as_index = False)['invoice_num'].count().head()
# Out:
#    customer_id         country  invoice_num
# 0        12346  United Kingdom            1
# 1        12347         Iceland          182
# 2        12348         Finland           31
# 3        12349           Italy           73
# 4        12350          Norway           17

# %%
# data visualization

# %%
orders = new_df.groupby(['customer_id','country'],as_index = False)['invoice_num'].count()

orders
# Out:
#       customer_id         country  invoice_num
# 0           12346  United Kingdom            1
# 1           12347         Iceland          182
# 2           12348         Finland           31
# 3           12349           Italy           73
# 4           12350          Norway           17
# ...           ...             ...          ...
# 4342        18280  United Kingdom           10
# 4343        18281  United Kingdom            7
# 4344        18282  United Kingdom           12
# 4345        18283  United Kingdom          756
# 4346        18287  United Kingdom           70
#
# [4347 rows x 3 columns]

# %%
orders.sort_values(by = 'invoice_num',ascending = False)
# Out:
#       customer_id         country  invoice_num
# 4019        17841  United Kingdom         7847
# 1888        14911            EIRE         5677
# 1298        14096  United Kingdom         5111
# 334         12748  United Kingdom         4596
# 1670        14606  United Kingdom         2700
# ...           ...             ...          ...
# 2567        15823  United Kingdom            1
# 4333        18268  United Kingdom            1
# 4310        18233  United Kingdom            1
# 4271        18184  United Kingdom            1
# 0           12346  United Kingdom            1
#
# [4347 rows x 3 columns]

# %%
# check top 5 most no.of orders
orders.sort_values(by = 'invoice_num',ascending = False).head()
# Out:
#       customer_id         country  invoice_num
# 4019        17841  United Kingdom         7847
# 1888        14911            EIRE         5677
# 1298        14096  United Kingdom         5111
# 334         12748  United Kingdom         4596
# 1670        14606  United Kingdom         2700

# %%
# Number of Orders for different Customers

plt.subplots(figsize = (15,6))

plt.xlabel('Customer_ID')
plt.ylabel('Invoice_Num')

plt.plot(orders.customer_id,orders.invoice_num)

# %%
new_df.head()
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
# 2      536365 2010-12-01 08:26:00      201012     12    3     8     84406B
# 3      536365 2010-12-01 08:26:00      201012     12    3     8     84029G
# 4      536365 2010-12-01 08:26:00      201012     12    3     8     84029E
#
#                            description  quantity  unit_price  amount_spent  \
# 0   white hanging heart t-light holder         6        2.55         15.30
# 1                  white metal lantern         6        3.39         20.34
# 2       cream cupid hearts coat hanger         8        2.75         22.00
# 3  knitted union flag hot water bottle         6        3.39         20.34
# 4       red woolly hottie white heart.         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# ...

# %%
new_df.groupby('invoice_num')['year_month'].unique().value_counts()
# Out:
# year_month
# [201111]    2658
# [201110]    1929
# [20119]     1756
# [20115]     1555
# [201012]    1400
# [20116]     1393
# [20117]     1331
# [20113]     1321
# [20118]     1281
# [20114]     1149
# [20112]      998
# [20111]      987
# [201112]     778
# Name: count, dtype: int64

# %%
new_df.groupby('invoice_num')['year_month'].unique().value_counts().sort_index().plot(kind = 'bar',figsize = (15,8))

plt.title('Number of Oreders for Different Months',fontsize = 30)
plt.xlabel('Year_Month',fontsize = 20)
plt.ylabel('Number Of Oreders',fontsize = 20)
# Out:
# Text(0, 0.5, 'Number Of Oreders')

# %%
new_df.groupby('invoice_num')['day'].unique()
# Out:
# invoice_num
# 536365    [3]
# 536366    [3]
# 536367    [3]
# 536368    [3]
# 536369    [3]
#          ...
# 581583    [5]
# 581584    [5]
# 581585    [5]
# 581586    [5]
# 581587    [5]
# Name: day, Length: 18536, dtype: object

# %%
new_df.groupby('invoice_num')['day'].unique().value_counts()
# Out:
# day
# [4]    4033
# [3]    3455
# [2]    3185
# [1]    2863
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
new_df.groupby('invoice_num')['day'].unique().value_counts().sort_index()
# Out:
# day
# [1]    2863
# [2]    3185
# [3]    3455
# [4]    4033
# [5]    2831
# [7]    2169
# Name: count, dtype: int64

# %%
new_df.groupby('invoice_num')['day'].unique().value_counts().sort_index().plot(kind = 'bar',figsize = (15,8))

plt.title('Number of Orders for Different Days',fontsize = 30)
plt.xlabel('Day',fontsize = 20)
plt.ylabel('Number Of Orders',fontsize = 20)
# Out:
# Text(0, 0.5, 'Number Of Orders')

# %%
new_df.unit_price.describe()
# Out:
# count    397924.000000
# mean          3.116174
# std          22.096788
# min           0.000000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: unit_price, dtype: float64

# %%
plt.boxplot(new_df.unit_price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16e0a2c04d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16e0a2d0990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16e031cdf10>],
#  'medians': [<matplotlib.lines.Line2D at 0x16e0a2c2410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16e0a2c2b90>],
#  'means': []}

# %%
# Filter only free products(cost = 0)

# %%
new_df[new_df['unit_price'] == 0]
# Out:
#        invoice_num        invoice_date  year_month  month  day  hour  \
# 9302        537197 2010-12-05 14:02:00      201012     12    7    14
# 33576       539263 2010-12-16 14:36:00      201012     12    4    14
# 40089       539722 2010-12-21 13:45:00      201012     12    2    13
# 47068       540372 2011-01-06 16:41:00       20111      1    4    16
# 47070       540372 2011-01-06 16:41:00       20111      1    4    16
# 56674       541109 2011-01-13 15:10:00       20111      1    4    15
# 86789       543599 2011-02-10 13:08:00       20112      2    4    13
# 130188      547417 2011-03-23 10:25:00       20113      3    3    10
# 139453      548318 2011-03-30 12:45:00       20113      3    3    12
# 145208      548871 2011-04-04 14:42:00       20114      4    1    14
# 157042      550188 2011-04-14 18:57:00       20114      4    4    18
# 187613      553000 2011-05-12 15:21:00       20115      5    4    15
# 198383      554037 2011-05-20 14:13:00       20115      5    5    14
# ...

# %%
len(new_df[new_df.unit_price == 0])
# Out:
# 40

# %%
zero_prods = new_df[new_df.unit_price == 0]

# %%
zero_prods.year_month
# Out:
# 9302      201012
# 33576     201012
# 40089     201012
# 47068      20111
# 47070      20111
# 56674      20111
# 86789      20112
# 130188     20113
# 139453     20113
# 145208     20114
# 157042     20114
# 187613     20115
# 198383     20115
# 279324     20117
# 282912     20117
# 285657     20118
# 298054     20118
# 314745     20118
# 314746     20118
# 314747     20118
# 314748     20118
# 358655     20119
# 361825     20119
# 379913    201110
# 395529    201110
# 420404    201110
# 436428    201111
# 436597    201111
# 436961    201111
# 439361    201111
# 446125    201111
# 446793    201111
# 446794    201111
# 454463    201111
# 454464    201111
# 479079    201111
# 479546    201111
# 480649    201111
# 485985    201111
# 502122    201111
# Name: year_month, dtype: int64

# %%
zero_prods.year_month.value_counts()
# Out:
# year_month
# 201111    14
# 20118      6
# 201012     3
# 201110     3
# 20111      3
# 20117      2
# 20113      2
# 20114      2
# 20115      2
# 20119      2
# 20112      1
# Name: count, dtype: int64

# %%
zero_prods.year_month.value_counts().sort_index()
# Out:
# year_month
# 20111      3
# 20112      1
# 20113      2
# 20114      2
# 20115      2
# 20117      2
# 20118      6
# 20119      2
# 201012     3
# 201110     3
# 201111    14
# Name: count, dtype: int64

# %%
zero_prods.year_month.value_counts().sort_index().plot(kind = 'bar',figsize = (12,7))

plt.title('Frequency for different Months (Dec 2010 - Dec 2011)')
plt.xlabel('Month')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
new_df.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom

# %%
# How much money spent by each country?

# %%
new_df.groupby('country')['invoice_num'].count()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# ...

# %%
new_df.groupby('country')['invoice_num'].count().sort_index()
# Out:
# country
# Australia                 1185
# Austria                    398
# Bahrain                     17
# Belgium                   2031
# Brazil                      32
# Canada                     151
# Channel Islands            748
# Cyprus                     614
# Czech Republic              25
# Denmark                    380
# EIRE                      7238
# European Community          60
# Finland                    685
# France                    8342
# Germany                   9042
# Greece                     145
# Iceland                    182
# Israel                     248
# Italy                      758
# Japan                      321
# Lebanon                     45
# Lithuania                   35
# Malta                      112
# Netherlands               2363
# Norway                    1072
# Poland                     330
# Portugal                  1462
# RSA                         58
# Saudi Arabia                 9
# Singapore                  222
# ...

# %%
country = new_df.groupby('country')['invoice_num'].count().sort_values().plot(kind = 'barh',figsize = (6,6))

country
# Out:
# <Axes: ylabel='country'>

# %%
country = new_df.groupby('country')['invoice_num'].count().sort_values()
del country['United Kingdom']

country.plot(kind = 'barh',figsize = (6,6))
# Out:
# <Axes: ylabel='country'>

# %%
new_df.head(2)
# Out:
#   invoice_num        invoice_date  year_month  month  day  hour stock_code  \
# 0      536365 2010-12-01 08:26:00      201012     12    3     8     85123A
# 1      536365 2010-12-01 08:26:00      201012     12    3     8      71053
#
#                           description  quantity  unit_price  amount_spent  \
# 0  white hanging heart t-light holder         6        2.55         15.30
# 1                 white metal lantern         6        3.39         20.34
#
#    customer_id         country
# 0        17850  United Kingdom
# 1        17850  United Kingdom

# %%
# How much money spent by each country?

# %%
new_df.groupby('country')['amount_spent'].sum()
# Out:
# country
# Australia                138521.310
# Austria                   10198.680
# Bahrain                     548.400
# Belgium                   41196.340
# Brazil                     1143.600
# Canada                     3666.380
# Channel Islands           20450.440
# Cyprus                    13590.380
# Czech Republic              826.740
# Denmark                   18955.340
# EIRE                     265545.900
# European Community         1300.250
# Finland                   22546.080
# France                   209024.050
# Germany                  228867.140
# Greece                     4760.520
# Iceland                    4310.000
# Israel                     7221.690
# Italy                     17483.240
# Japan                     37416.370
# Lebanon                    1693.880
# Lithuania                  1661.060
# Malta                      2725.590
# Netherlands              285446.340
# Norway                    36165.440
# Poland                     7334.650
# ...

# %%
new_df.groupby('country')['amount_spent'].sum().sort_values()
# Out:
# country
# Saudi Arabia                145.920
# Bahrain                     548.400
# Czech Republic              826.740
# RSA                        1002.310
# Brazil                     1143.600
# European Community         1300.250
# Lithuania                  1661.060
# Lebanon                    1693.880
# United Arab Emirates       1902.280
# Unspecified                2667.070
# Malta                      2725.590
# USA                        3580.390
# Canada                     3666.380
# Iceland                    4310.000
# Greece                     4760.520
# Israel                     7221.690
# Poland                     7334.650
# Austria                   10198.680
# Cyprus                    13590.380
# Italy                     17483.240
# Denmark                   18955.340
# Channel Islands           20450.440
# Singapore                 21279.290
# Finland                   22546.080
# Portugal                  33439.890
# Norway                    36165.440
# ...

# %%
money_spent = new_df.groupby('country')['amount_spent'].sum().sort_values()

money_spent.plot(kind = 'barh',figsize = (6,6))
plt.xlabel('Money Spent (Dollar)', fontsize=12)
plt.ylabel('Country', fontsize=12)
plt.title('Money Spent by different Countries', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Money Spent by different Countries')

# %%
money_spent = new_df.groupby('country')['amount_spent'].sum().sort_values()
del money_spent['United Kingdom'] 

money_spent.plot(kind = 'barh',figsize = (6,6))
# Out:
# <Axes: ylabel='country'>

# %%
# This is called Data Analysis :)
